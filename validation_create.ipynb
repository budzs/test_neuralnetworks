# %% [markdown]
# <a href="https://colab.research.google.com/github/budzs/test_neuralnetworks/blob/master/validation_create.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip  /content/drive/MyDrive/NN/ppke-itk-neural-networks-otp-2020-challenge.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/Algae.Chlorophyta.Scenedesmus/DHM202015100700020151105T0954480003.png
#   inflating: ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/Algae.Chlorophyta.Scenedesmus/DHM202015100700020151105T0955000004.png
#   inflating: ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/Algae.Chlorophyta.Scenedesmus/DHM202015100700020151105T0955160001.png
#   inflating: ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/Algae.Chlorophyta.Scenedesmus/DHM202015100700020151105T0955200001.png
#   inflating: ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/Algae.Chlorophyta.Scenedesmus/DHM202015100700020151105T0956390001.png
# ...

# %% [markdown]
# Creating a validation folder

# %%
import os, random, shutil

path = '/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation'

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

list = os.listdir('/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train') # dir is your directory path
number_files = len(list)
print (number_files)
dir= '/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train'
# Out:
# Successfully created the directory /content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation
# 16

# %% [markdown]
# Creating folders into validation validation folder
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# Hány százalék legyen tanító és hány validáló

# %%
import random
for i in range(20):
  #print((random.randint(0,9) <2) == True)
  if ((random.randint(0,9) < 2) == True):
        print('siker')
# Out:
# siker
# siker
# siker
# siker

# %%
d= '/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train'
for (root, subDirs, files) in os.walk(d):  
    for subDir in subDirs: 
        print(subDir)
        list = os.listdir(d+'/'+subDir)
        num_of_f = len(list)
        print (num_of_f)
        path = '/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation/'+subDir
        try:
          os.mkdir(path)
        except OSError:
           print ("Creation of the directory %s failed" % path)
        else:
              print ("Successfully created the directory %s " % path)
# Out:
# Algae.Chlorophyta.Monoraphidium
# 419
# Successfully created the directory /content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation/Algae.Chlorophyta.Monoraphidium
# Bacteria.Cyanobacteria.Spirulina
# 198
# Successfully created the directory /content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation/Bacteria.Cyanobacteria.Spirulina
# Algae.Chlorophyta.Coelastrum
# 276
# Successfully created the directory /content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation/Algae.Chlorophyta.Coelastrum
# Bacteria.Cyanobacteria.Cyanobacteria_coenobia
# 306
# Successfully created the directory /content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation/Bacteria.Cyanobacteria.Cyanobacteria_coenobia
# Algae.Bacillariophyta.Nitzschia_acicularis
# 312
# ...

# %%
import random
d='/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/'
for (root, subDirs, files) in os.walk(d):
  for subDir in subDirs:
    list = os.listdir(d+'/'+subDir)
    num_of_f = len(list)
    source='/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/train/'+subDir+'/'
    dest='/content/ppke-itk-neural-networks-otp-2020-challenge/NN_2020_Kaggle_dataset/validation/'+subDir+'/'
    for file in list:
      if ((random.randint(0,9) < 2) == True):
        _source = (source+file)
        _dest=(dest)
        shutil.move(_source,_dest)
        print(file,"Files Moved Successfully")
# Out:
# Streaming output truncated to the last 5000 lines.
# DHM2020151007Measurement20160215_11512020160223T1643330001.png
# siker
# DHM2020151007Measurement20160215_11512020160223T1643330001.png Files Moved Successfully
# 05782DHM2020151007Measurement20160524_14284920160609T1233570004.png
# 03251DHM2020151007Measurement20160524_14284920160609T1328560004.png
# DHM202015100700020151013T1240450004.png
# siker
# DHM202015100700020151013T1240450004.png Files Moved Successfully
# 03681DHM2020151007Measurement20160524_14284920160609T1350060002.png
# DHM2020151007Measurement20160215_11512020160224T0533080001.png
# siker
# DHM2020151007Measurement20160215_11512020160224T0533080001.png Files Moved Successfully
# DHM2020151007Measurement20160215_11512020160223T2216170001.png
# siker
# DHM2020151007Measurement20160215_11512020160223T2216170001.png Files Moved Successfully
# HortobagyHalastoIvadekNeveloTo20140529T1117330002.png
# DHM2020151007Measurement20160215_11512020160224T0837250001.png
# ...
